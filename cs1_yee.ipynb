# %% [markdown]
# <a href="https://colab.research.google.com/github/jarvis1-tech/cs1-python-emerald-yee/blob/main/cs1_yee.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Grade 7!")
# Out:
# Hello Grade 7!
